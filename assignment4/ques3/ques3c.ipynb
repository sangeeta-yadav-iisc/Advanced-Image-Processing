# %%
import numpy as np
import h5py
import scipy.io as sio
from scipy import stats
test = sio.loadmat('hw5/hw5.mat')

# %%
# print(test['refnames_blur'])
print(test['blur_dmos'][0])
# print(test['blur_orgs'])
# Out:
# [42.12776536 37.46272032 43.26456019 19.51009708 72.82942221 54.7958498
#  28.45923879 28.18091287 23.8350667  89.72374712 83.26954045 23.74780059
#  30.5144452  33.31736518 43.37139347 63.38193548 88.25341458 32.28879444
#  53.1730823  41.46837268 39.15756415 47.53983951 19.81956589 93.40865466
#  60.85908908 43.11752292 32.45533469 22.96359302 29.70711262 50.7828911
#  52.16809315 20.42170139 37.06966909 46.75861494 29.94692105 49.38873156
#  55.79859697 49.57258125 35.1634189  59.72797576 64.24080369 37.61345259
#  41.3629839  26.58823692 21.68033867 21.37173574 48.37779846 57.04099416
#  35.51107642 46.66501376 21.90766425 68.54058129 59.56781456 59.07594074
#  50.3000219  37.03663806 53.61327167 72.87394932 43.22494778 20.19888494
#  26.81042493 33.28958774 18.63878203 38.73011028 41.54577165 58.91249145
#  22.83897811 64.7162926  79.759024   75.36497201 20.38173196 47.86237099
#  60.10697151 40.94953032 42.41840461 40.31616323 40.77253768 67.58397975
# ...

# %%
stats.spearmanr([1,2,3,4,5], [5,6,7,8,7])
